# %%
def my_return(x,y):
    a = x
    b = y
    return a,b

# %%
o = my_return(1,2)
id(o)
# Out:
# 140392666962368

# %%
type(o)
# Out:
# tuple

# %%
def l(x=1):
    x = x+1
    return x

# %%
a = [1,2]
id(a)
# Out:
# 140392666019776

# %%
a[1] = 2
id(a)
# Out:
# 140392666019776

# %%
a ={1:1,3:3,2:2}

# %%
a
# Out:
# {1: 1, 3: 3, 2: 2}

# %%
def power(x,*args,n=2,**kw):
    s = 1
    while n > 0:
        n = n - 1
        s = s * x
    print(*args)
    return s

# %%
power(2,3)
# Out:
# 3
# 4
